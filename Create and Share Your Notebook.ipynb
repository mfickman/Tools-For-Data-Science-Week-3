# %% [markdown]
# <h1>My Jupyter Notebook on IBM Watson Studio<h1>

# %% [markdown]
# <b>Mark Fickman</b><br>
# Current Job: Engineer/Developer/n<br>
# Desired Job: Data Scientist / Datga Engineer

# %% [markdown]
# <i>I am interested in data science because I would like my knowledge of python with my passion for math in order to bring insights to organizations while giving me a fufilling and worthwhile careeer</i>

# %% [markdown]
# I am adding one plus one

# %%
1 + 1
# Out:
# 2

# %% [markdown]
# <div>
#     <ul>
#         <li> bullet one </li>
#         <li> bullet two </li>
#     </ul>
# </div>
#
# <div>
#     <ol type="1">
#         <li> number one</li>
#         <li> number two</li>
#     </ol>
# </div>
#
# <div>
#     <img src="https://picsum.photos/200/300">
# </div>
